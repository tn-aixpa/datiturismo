# %%
from datasets_tourism import *
# Out:
# > 2024-09-17 12:17:41,897 [info] Project loaded successfully: {'project_name': 'overtourism'}

# %% [markdown]
# # Depuratore acqua

# %%
depuratore_df[["pioggia_mm", "uscita_mc", "bypass_mc", "date"]].plot(x="date", figsize=(25, 8))
# Out:
# <AxesSubplot: xlabel='date'>
